# %% [markdown]
# # MLOps: From Business Problem to Deployment with SageMaker, Lambda Function, and API Gateway

# %%
# Imports
import os
import boto3
import pandas as pd
import sagemaker
from sagemaker import get_execution_role
from sagemaker.inputs import TrainingInput
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 6
#       2 import os
#       3 import boto3
#       4 import pandas as pd
#       5 import sagemaker
# ----> 6 from sagemaker import get_execution_role
#       7 from sagemaker.inputs import TrainingInput
#       8 from sklearn.model_selection import train_test_split
#       9 import warnings
#
# ImportError: cannot import name 'get_execution_role' from 'sagemaker' (c:\Users\krupc\anaconda3\envs\pyml\Lib\site-packages\sagemaker\__init__.py)
